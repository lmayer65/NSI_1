# %% [markdown]
# # <u>Projet 2</u> : Création d'un jeu Pong avec la bibliothèque Pygame, partie III

# %%
# Installer le module pygame
# !pip install pygame

# %% [markdown]
# ## <u>Activité 6</u> : Utiliser des fonctions
# Voici un exemple de programme utilisant les fonctions

# %%
# Importation de la librairie pygame
import pygame,sys
from pygame.draw import *
from pygame.display import *

# Variables globales ##########################################################"
size = width, height = 500, 500 # taille de la fenêtre d'affichage
couleurFond = 255, 125, 125   # Couleur du fond

# Attributs de la balle
dx,dy = 3,1    # Vecteur de déplacement entre deux frames consécutives
couleurBalle = 0,0,255    # Couleur de la balle
x,y = 100,100             # Position initiale de la balle
r = 20                    # Rayon de la balle



############## ECRIRE ICI LA FONCTION AFFICHER ##############################
def afficherBalle():
    global x,y,couleurBalle,r
    circle(screen, couleurBalle , (x,y), r, 0)

############## ECRIRE ICI LA FONCTION DEPLACER ##############################
def deplacerBalle():
    global x,y,dx,dy
    x += dx
    y += dy

############## ECRIRE ICI LA FONCTION TESTCOLLISION ##############################
def testCollision() :
    global x,y,dx,dy,r,width,height
    if x < r or x + r > width  :  # Bords gauche /droite
        dx = -dx
    if y < r or y + r > height :  # Bords haut / bas
        dy = -dy

############## ECRIRE ICI LA FONCTION TESTEVENEMENT ##############################
def testEvenement() :
# Test d'arrêt du jeu
    for event in pygame.event.get():
        if event.type == pygame.QUIT:# Si clic sur la croix quitter
            pygame.display.quit()    # Ferme la fenêtre
            sys.exit()               # Arrête le programme
    
    
    
    
###############################################################################################################    
    
# Lancement de la bibliothèque pygame 
pygame.init()
            
# Affichage d'une fenêtre de dessin de largeur 500 pixels et de hauteur 500 pixels
screen = set_mode(size)

while True:
    # Remplissage du fond par la couleur blanche
    screen.fill(couleurFond)
    
    # Afficher la balle :
    afficherBalle()
    
    # Déplacement de la balle :
    deplacerBalle()
    
    # Test de collision
    testCollision()

    flip()                 # Activer le rendu graphique
    pygame.time.delay(15)  # Une image toutes les 15 ms
    
    # Test d'arrêt du jeu
    testEvenement()

# %% [markdown]
# ## <u>Activité 7</u> : Ajouter des balles
#
# On souhaite utiliser dans un premier temps <u>trois balles</u> dans le jeu, chacune d'entre elle devant avoir des attributs différents (position de départ, vitesse, couleur, rayon).
#
#
# <u>Remarque</u> : on utilisera des <u>listes</u> pour les attributs des balles et une boucle <i>for</i> utilisant la variable <i>nombreBalles</i> pour appeler les fonctions <i>afficher()</i>, <i>deplacer()</i> et <i>testCollision()</i>. On pourra aussi penser à passer un indice en paramètre des fonctions précédentes pour accéder facilement à chaque valeur des listes.

# %%
# Importation de la librairie pygame
import pygame,sys
from pygame.draw import *
from pygame.display import *

# Variables globales ##########################################################"
size = width, height = 500, 500 # Taille de la fenêtre d'affichage
couleurFond = 255, 125, 125     # Couleur du fond

                ### NOUVELLE VARIABLE ####
nombreBalles = 3                # Nombre de balles dans le jeu

# Attributs de la balle
dx,dy = 3,1    # Vecteur de déplacement entre deux frames consécutives
couleurBalle = 0,0,255    # Couleur de la balle
x,y = 100,100             # Position initiale de la balle
r = 20                    # Rayon de la balle



############## ECRIRE ICI LA FONCTION AFFICHER ##############################
def afficherBalle():
    global x,y,couleurBalle,r
    circle(screen, couleurBalle , (x,y), r, 0)

############## ECRIRE ICI LA FONCTION DEPLACER ##############################
def deplacerBalle():
    global x,y,dx,dy
    x += dx
    y += dy

############## ECRIRE ICI LA FONCTION TESTCOLLISION ##############################
def testCollision() :
    global x,y,dx,dy,r,width,height
    if x < r or x + r > width  :  # Bords gauche /droite
        dx = -dx
    if y < r or y + r > height :  # Bords haut / bas
        dy = -dy

############## ECRIRE ICI LA FONCTION TESTEVENEMENT ##############################
def testEvenement() :
# Test d'arrêt du jeu
    for event in pygame.event.get():
        if event.type == pygame.QUIT:# Si clic sur la croix quitter
            pygame.display.quit()    # Ferme la fenêtre
            sys.exit()               # Arrête le programme
    
    
    
    
###############################################################################################################    
    
# Lancement de la bibliothèque pygame 
pygame.init()
            
# Affichage d'une fenêtre de dessin de largeur 500 pixels et de hauteur 500 pixels
screen = set_mode(size)

while True:
    # Remplissage du fond par la couleur blanche
    screen.fill(couleurFond)
    
    # Afficher la balle :
    afficherBalle()
    
    # Déplacement de la balle :
    deplacerBalle()
    
    # Test de collision
    testCollision()

    flip()                 # Activer le rendu graphique
    pygame.time.delay(15)  # Une image toutes les 15 ms
    
    # Test d'arrêt du jeu
    testEvenement()

# %% [markdown]
# <b><u>Question</u></b>  : <b>Modifier</b> le programme suivant pour qu'il permette l'affichage de 3 balles. On donnera les valeurs souhaitées aux balles.
#
# ### <u>Appeler le professeur</u> une fois l'activité terminée.

# %% [markdown]
# ## <u>Activité 8</u> : Un peu de hasard
#
# Il n'est pas commode d'ajouter à la main les attributs de chaque balle. Pour cela, on va utiliser la fonction <i>randint</i> de la bibliothèque <i>random</i>.
#
# Voilà un exemple (à tester plusieurs fois) :

# %%
from random import randint    # Importation de la fonction randint

print(randint(-5,5))          # Affiche des valeurs aléatoires entières entre -5 et 5

# %% [markdown]
# <b><u>Question</u></b> : <b>Modifier</b> alors le programme précédent pour qu'il affiche 30 balles, toutes générées aléatoirement. <b>On choisira des valeurs d'attributs adaptées !</b>
#
# <u>Remarque</u> : on utilisera la méthode <i>append()</i> des listes pour les remplir (cf cours).
#
# ### <u>Appeler le professeur</u> une fois l'activité terminée.

# %% [markdown]
# ## <u>Activité 9</u> : Ajout de la raquette
#
# Par convention, on ajoutera la raquette à gauche de l'écran. Elle peut se déplacer de haut en bas, son abscisse reste donc fixe mais son ordonnée sera commandée par les touches du clavier.
#
# On ajoute donc des attributs pour la raquette :
# ![Sans%20titre.png](attachment:Sans%20titre.png)
#
# <u>Remarque</u> : on peut utiliser un n-tuple comme paramètre dans la méthode <i>rect</i>, comme ceci :
# <b> rect(screen,rcolor,(rx,ry,rw,rh)).</b>
#
# <b><u>Question</u></b> : <b>Compléter</b> le programme ci-dessous aux endroits indiqués pour qu'il affiche la raquette. On n'oubliera pas le mot-clé <i>global</i> dans la fonction <i>afficherRaquette()</i>.

# %%
# Importation de la librairie pygame
import pygame,sys
from pygame.draw import *
from pygame.display import *

# Variables globales ##########################################################"
size = width, height = 500, 500 # Taille de la fenêtre d'affichage
couleurFond = 255, 125, 125     # Couleur du fond


# Attributs de la balle
dx,dy = 3,1    # Vecteur de déplacement entre deux frames consécutives
couleurBalle = 0,0, 255    # Couleur de la balle
x,y = 100, 100             # Position initiale de la balle
r = 20                    # Rayon de la balle

############ ECRIRE ICI LES ATTRIBUTS DE LA RAQUETTE   ######################




############## ECRIRE ICI LA FONCTION AFFICHER ##############################
def afficherBalle():
    global x,y,couleurBalle,r
    circle(screen, couleurBalle , (x,y), r, 0)

############## ECRIRE ICI LA FONCTION DEPLACER ##############################
def deplacerBalle():
    global x,y,dx,dy
    x += dx
    y += dy

############## ECRIRE ICI LA FONCTION TESTCOLLISION ##############################
def testCollision() :
    global x,y,dx,dy,r,width,height
    if x < r or x + r > width  :  # Bords gauche /droite
        dx = -dx
    if y < r or y + r > height :  # Bords haut / bas
        dy = -dy

############## ECRIRE ICI LA FONCTION TESTEVENEMENT ##############################
def testEvenement() :
    # Test d'arrêt du jeu
    for event in pygame.event.get():
        if event.type == pygame.QUIT:# Si clic sur la croix quitter
            pygame.display.quit()    # Ferme la fenêtre
            sys.exit()               # Arrête le programme
    
    
################# ECRIRE ICI LA FONCTION AFFICHER RAQUETTE  #######################   
def afficherRaquette() :
    



    
###############################################################################################################    
    
# Lancement de la bibliothèque pygame 
pygame.init()
            
# Affichage d'une fenêtre de dessin de largeur 500 pixels et de hauteur 500 pixels
screen = set_mode(size)

while True:
    # Remplissage du fond par la couleur blanche
    screen.fill(couleurFond)
    
    # Afficher la balle :
    afficherBalle()
    
    # Déplacement de la balle :
    deplacerBalle()
    
    # Afficher la raquette
    afficherRaquette()
    
    # Test de collision
    testCollision()

    flip()                 # Activer le rendu graphique
    pygame.time.delay(15)  # Une image toutes les 15 ms
    
    # Test d'arrêt du jeu
    testEvenement()

# %% [markdown]
# ## <u>Activité 10</u> : Déplacement de la raquette
#
# On a besoin d'interagir avec le clavier (flèche du haut et flèche du bas) pour commander la position de la raquette.
#
# ![Sans%20titre.png](attachment:Sans%20titre.png)

# %% [markdown]
# On créé la fonction <i>bougerRaquette</i> et modifie alors la fonction <i>testEvenements()</i> en ajoutant ces lignes de code :

# %%
def testEvenements():
    for event in pygame.event.get():
        if event.type == QUIT:       # Si clique sur la croix quitter
            pygame.display.quit()    # Ferme la fenêtre
            sys.exit()  # Arrête le programme
        if event.type == KEYDOWN:    # Une touche clavier a été pressée
            bougerRaquette()

# %% [markdown]
# Et enfin, cette instruction permet de gérer l'appui en continu sur une touche de clavier :
# ![Sans%20titre.png](attachment:Sans%20titre.png)
#
# Elle est à rajouter juste après l'initialisation de la librairie pygame.

# %%
# Importation de la librairie pygame
import pygame,sys
from pygame.draw import *
from pygame.display import *
from pygame.locals import *    # Nouvelles fonction importées

# Variables globales ##########################################################"
size = width, height = 500, 500 # Taille de la fenêtre d'affichage
couleurFond = 255, 125, 125     # Couleur du fond


# Attributs de la balle
dx,dy = 3,1    # Vecteur de déplacement entre deux frames consécutives
couleurBalle = 0,0, 255    # Couleur de la balle
x,y = 100, 100             # Position initiale de la balle
r = 20                    # Rayon de la balle

############ ECRIRE ICI LES ATTRIBUTS DE LA RAQUETTE   ######################
rx = 20             # rx,ry : position de la raquette
ry = height/2
rw = 20             # rw, rh : taille de la raquette
rh  = 100
rdy = 5             # Vitesse de déplacement de la raquette
couleurRaquette = 255, 255, 255   # Couleur de la raquette


############## ECRIRE ICI LA FONCTION AFFICHER ##############################
def afficherBalle():
    global x,y,couleurBalle,r
    circle(screen, couleurBalle , (x,y), r, 0)

############## ECRIRE ICI LA FONCTION DEPLACER ##############################
def deplacerBalle():
    global x,y,dx,dy
    x += dx
    y += dy

############## ECRIRE ICI LA FONCTION TESTCOLLISION ##############################
def testCollision() :
    global x,y,dx,dy,r,width,height
    if x < r or x + r > width  :  # Bords gauche /droite
        dx = -dx
    if y < r or y + r > height :  # Bords haut / bas
        dy = -dy

############## ECRIRE ICI LA FONCTION TESTEVENEMENT ##############################
def testEvenements():
    for event in pygame.event.get():
        if event.type == QUIT:       # Si clique sur la croix quitter
            pygame.display.quit()    # Ferme la fenêtre
            sys.exit()  # Arrête le programme
        if event.type == KEYDOWN:    # Une touche clavier a été pressée
            bougerRaquette()
    
    
################# ECRIRE ICI LA FONCTION AFFICHER RAQUETTE  #######################   
def afficherRaquette() :
    global rx,ry,rw,th,couleurRaquette
    rect(screen,couleurRaquette,(rx,ry,rw,rh))


################# ECRIRE ICI LA FONCTION BOUGER RAQUETTE  #######################   
def bougerRaquette() :
    global ry,rdy
    if pygame.key.get_pressed()[K_UP]:  # Si on appuie sur la flèche-haut, la raquette monte de rdy
       
    if pygame.key.get_pressed()[K_DOWN]:# Si on appuie sur la flèche-bas, la raquette descend de rdy
        
        
###############################################################################################################    
    
# Lancement de la bibliothèque pygame 
pygame.init()

# Autorise l'appui en continu sur une touche de clavier
pygame.key.set_repeat(10,10)
            
# Affichage d'une fenêtre de dessin de largeur 500 pixels et de hauteur 500 pixels
screen = set_mode(size)

while True:
    # Remplissage du fond par la couleur blanche
    screen.fill(couleurFond)
    
    # Afficher la balle :
    afficherBalle()
    
    # Déplacement de la balle :
    deplacerBalle()
    
    # Afficher la raquette
    afficherRaquette()
    
    # Test de collision
    testCollision()

    flip()                 # Activer le rendu graphique
    pygame.time.delay(15)  # Une image toutes les 15 ms
    
    # Test d'arrêt du jeu
    testEvenements()

# %% [markdown]
# 1/ <b>Compléter</b> la fonction <i>bougerRaquette()</i> du programme ci-dessus :
#
# 2/ <b>Modifier</b> le code pour que la raquette ne sorte pas de l'écran.
#
# ### <u>Appeler le professeur</u> une fois les modifications effectuées.
