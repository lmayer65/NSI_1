# %% [markdown]
# # <u>Thème</u> : générer un terrain en 3D, Partie 3
#
# ## <u>Activité 5</u> : Recherche d'un extremum

# %% [markdown]
# On possède un terrain généré à l'aide des bruits de Perlin de taille 256 * 256 stocké dans la variable *tabDefinitifCalque*.
# On souhaite trouver le point d'altitude maximal de ce terrain et connaître ses coordonnées.
#
# <b><u>Question</u></b> : <b>Compléter</b> la fonction nommée `maximum(tailleTerrain,tabValeurs)` permettant de trouver <u>le point d'altitude maximal</u> de ce terrain et de <u>connaître ses coordonnées</u>. Elle a en paramètres la variable `tailleTerrain`taille du terrain (entier) et la variable `tabValeurs` contenant les coordonnées du terrain après traitement par l'algorithme de Perlin.

# %%
###########################################################################################################
########################## Ne pas changer cette partie du programme #######################################
###########################################################################################################

with open('FonctionsAuxiliaires.py') as f : exec(f.read())


# Paramètres du terrain
tailleTerrain = 256
persistanceInitiale = 0.6
nombreOctaves = 4
frequenceInitiale = 4
hauteurMaximale = 100

# Génération du tableau qui regroupe les nombres aléatoires de base
tabBaseCalque = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]

# Choix de l'utilisation de l'interpolation cubique
choixInterpolationCubique = True

# Création du calque définitif
tabValeurs = creationCalqueDefinitif(nombreOctaves,tailleTerrain,frequenceInitiale,tabBaseCalque,
                                             persistanceInitiale,choixInterpolationCubique)

# Affichage du terrain
affichageTerrain(tailleTerrain,tabValeurs,hauteurMaximale)


#######################################################################################################################
####### Compléter ci-dessous la fonction permettant de trouver le point d'altitude maximal et ses coordonnées #########
#######################################################################################################################

def maximum(tailleTerrain,tabValeurs):
    return True
    
    
#####################################################################################################



# Détermination des coordonnées correspondant au sommet du terrain
pointMaxi = maximum(tailleTerrain,tabValeurs)

#####################################################################################################
####################### Compléter pour l'affichage des résultats ####################################
#####################################################################################################

print()

#####################################################################################################

# %% [markdown]
# <u>Aide</u> : utiliser le jeu de test proposé ci-dessous pour vérifier votre fonction.

# %%
# Tester votre fonction sur le jeu de test suivant qui est un tableau de dimension 256*256 et 
# où la hauteur maximale est de 150, atteinte au point de coordonnées (25;100). 

jeuDeTest = [[0 for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]
jeuDeTest[25][100]=150

pointMaxiTest=maximum(tailleTerrain,jeuDeTest)

############ Afficher ici l'altitude de pointMaxiTest et ses coordonnées #####################

# %% [markdown]
# ### <u>Appeler le professeur pour validation</u>

# %% [markdown]
# ---
#
# ## <u>Activité 6</u> :  Génération d'une île centrale
#
# On souhaite générer un terrain en 3D sur lequel il y a une île centrale.
#
# <b><u>IMPORTANT</u></b> : <b>Attendre les explications du professeur.</b>
#
#
# <u><b>Question</b></u> : <b>Compléter</b> la fonction `creationIle` pour créer un terrain avec un île (entourée d'eau).
#
# <u>Aide</u> : Reprendre le cours sur les algorithmes des k plus proches voisins avec les différents types de distance.

# %%
###########################################################################################################
########################## Ne pas changer cette partie du programme #######################################
###########################################################################################################

with open('FonctionsAuxiliaires.py') as f : exec(f.read())

# Paramètres du terrain
tailleTerrain = 256
persistanceInitiale = 0.6
nombreOctaves = 4
frequenceInitiale = 2
hauteurMaximale = 100


# Génération du tableau qui regroupe les nombres aléatoires de base
tabBaseCalque = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]

###########################################################################################################
# Paramètres de l'île (à modifier si besoin)
rayonIle = 50
hauteurIle = 80

###########################################################################################################
#################### Compléter ci-dessous la fonction créant une île: ############################
###########################################################################################################

def creationIle():
    return True
    

tabValeurs = creationIle()  # Ne pas modifier tabValeurs, elle est utilisée après !

###########################################################################################################
########################### Ne pas changer la suite du programme ##########################################
###########################################################################################################

# Choix de l'utilisation de l'interpolation cubique
choixInterpolationCubique = True

#Création du calque définitif
tabDefinitifCalque = creationCalqueDefinitif(nombreOctaves,tailleTerrain,frequenceInitiale,tabValeurs,
                                             persistanceInitiale,choixInterpolationCubique)

# Affichage du terrain
affichageTerrain(tailleTerrain,tabDefinitifCalque,hauteurMaximale)

# %% [markdown]
# ### <u>Appeler le professeur pour validation</u>
