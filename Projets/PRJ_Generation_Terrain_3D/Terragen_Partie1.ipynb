# %% [markdown]
# # Thème : générer un terrain en 3D, Partie I
#
#
# ## <u>Activité 1</u> : Une première idée : le tout aléatoire

# %% [markdown]
# On souhaite générer un terrain en 3D de taille 256 * 256 avec des hauteurs aléatoires comprises entre 0 et 100 unités.
#
# <u>Rappel</u> : on utilisera la fonction randint(a,b) qui permet de générer un nombre aléatoire entier entre a et b comme le montre le programme suivant que l'on pourra exécuter.

# %%
from random import randint

for i in range(0,25) :
    print(randint(0,50))

# %% [markdown]
# <b>1/</b> : <b>Générer</b> un tableau de 256 * 256 avec des hauteurs aléatoires comprises entre 0 et 100 unités dans une variable nommée `tabValeurs` ci-dessous puis <b>exécuter</b> le programme.
#
# <u>Aide</u> : Reprendre le cours sur la construction de listes par compréhension si nécessaire.
#
# <b><u>Important</u> : il se peut qu'un message étrange du type `<Figure size 2000x2000 with 3 Axes>` s'affiche : Il suffit d'exécuter à nouveau le programme et tout fonctionnera correctement. Je n'ai pas d'explication à ce phénomène à ce jour ...

# %%
from random import randint

# Importe et exécute les fonctions auxiliaires
with open('FonctionsAuxiliaires.py') as f : exec(f.read())

            
# Paramètres du terrain
tailleTerrain = 256
hauteurMaximale = 100


###########################################################################################################
############### Ecrire ci-dessous l'algorithme générant et complétant la variable tabValeurs ##############
###########################################################################################################



###########################################################################################################



###########################################################################################################
########################### Ne pas changer la suite du programme ##########################################
###########################################################################################################

# Construction de l'image à partir de tabValeurs
image = constructionImage(tailleTerrain,tabValeurs,hauteurMaximale)

# Affichage de l'image et du terrain
affichageImageTerrain(tailleTerrain,tabValeurs,hauteurMaximale,image)

###########################################################################################################

# %% [markdown]
# 2/ Le terrain obtenu est-il satisfaisant ? <b>Justifier</b>.
#
# ### <u>Appeler le professeur pour validation</u>
