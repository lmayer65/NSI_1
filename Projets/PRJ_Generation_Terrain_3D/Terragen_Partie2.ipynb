# %% [markdown]
# # <u>Thème</u> : générer un terrain en 3D réaliste, Partie II
#
# <u>Objectif</u> : Découverte de deux algorithmes répondant au thème

# %% [markdown]
# ## <u>Activité 2</u> :  Algorithme de Perlin
#
# On génère un terrain en 3D de taille 256 * 256 avec des hauteurs comprises entre 0 et 100 unités à l'aide de l'algorithme de Perlin.
#
# Le programme est écrit ci-dessous.
#
# <b>On cherche à déterminer expérimentalement le rôle des variables `nombreOctaves`, `frequenceInitiale`, `persistanceInitiale` et `choixInterpolationCubique` par tests successifs.</b>
#
# <u>Rappels</u> sur la démarche expérimentale :
# <ul>
# <li> UNE SEULE variable doit être modifiée à la fois pour respecter la démarche expérimentale </li>
#     <li> <b>Penser</b> à remettre la variable à sa valeur par défaut avant d'en tester une autre ! </li>
#
# </ul>

# %% [markdown]
# 1/ En <u>testant diverses valeurs</u> et en <u>respectant leur type</u>, <b>indiquer</b> le rôle des variables :
#
# a) `nombreOctaves` :
# b) `frequenceInitiale` :
# c) `persistanceInitiale` :
# d) `choixInterpolationCubique` :
#
# ### <u>Appeler le professeur pour validation</u>

# %%
with open('FonctionsAuxiliaires.py') as f : exec(f.read())


##########################################################################################################           
################################## Paramètres du terrain #################################################
##########################################################################################################

# Valeurs pour tailleTerrain : 256,512 ou 1024
tailleTerrain = 256

# Type : entier non signé non nul
############################### A ne pas modifier !! #####################################################
hauteurMaximale = 100


# Type : entier non signé non nul entre 1 et 6
# Nombre de calque à appliquer pour obtenir le calque final
nombreOctaves = 2


# De valeur 1,2,4 ou 8
# Donne la partition de chaque calque (doublée par calque successif)
frequenceInitiale = 2


# Type : nombre à virgule flottante entre 0.0 et 1.0
# Donne le poids (divisé par deux par calque successif) d'un calque
persistanceInitiale = 0.3


# Type : booléen
# Permet une interpolation plus fine si la valeur est True.
choixInterpolationCubique = False


###########################################################################################################



###########################################################################################################
########################### Ne pas changer la suite du programme ##########################################
###########################################################################################################

# Initialisation des valeurs aléatoires de départ
tabInitial = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]



# Génération du calque définitif (valeurs finales des hauteurs du terrain)
tabFinal = creationCalqueDefinitif(nombreOctaves,tailleTerrain,frequenceInitiale,tabInitial,
                            persistanceInitiale,choixInterpolationCubique)



# Création de l'image
image = constructionImage(tailleTerrain,tabFinal,hauteurMaximale)

# Affichage de l'image et du terrain
affichageImageTerrain(tailleTerrain,tabFinal,hauteurMaximale,image)

# %% [markdown]
# 2/ <b>Proposer</b> des valeurs aux variables suivantes pour que le <b>terrain généré paraisse réaliste</b>.
#
# a) `nombreOctaves` :
# b) `frequenceInitiale` :
# c) `persistanceInitiale` :
# d) `choixInterpolationCubique` :
#
#
# <u>Remarque</u> : Toute combinaison de valeurs proposée créant un terrain réaliste sera bien sûr acceptée.
#
# ### <u>Appeler le professeur pour validation</u>

# %% [markdown]
# 3/ (*) <b>Tester</b> le programme avec `nombreOctaves` = 8 et `frequenceInitiale` = 4. <b>Que se passe-t-il</b> ?
#
# <b>Proposer</b> une explication et <b>indiquer</b> comment remédier à ce problème en modifiant éventuellement les valeurs d'autres variables.
#
# ### <u>Appeler le professeur pour validation</u>

# %% [markdown]
# ## <u>Activité 3</u> : L'algorithme diamant-carré ##
#
#
# On génère un terrain en 3D de taille 256 * 256 avec des hauteurs comprises entre 0 et 100 unités à l'aide de l'algorithme diamant-carré.
#
# Le programme est écrit ci-dessous.

# %%
with open('FonctionsAuxiliaires.py') as f : exec(f.read())

#############################################################################################################
################################## Paramètres du terrain ####################################################
#############################################################################################################

# Attention à être un multiple de 2 exp(n) + 1 , n entier naturel non nul :257, 513, 1025 ou 2049
################################### A ne pas modifier !! ####################################################
tailleTerrain = 513

# Type : entier non signé non nul
################################### A ne pas modifier !! ####################################################
hauteurMaximale = 100


# Type : nombre flottant entre 0.0 et 1.0
variabilite = 0.1   # A modifier





#############################################################################################################

# Génération du tableau qui contiendra les hauteurs du terrain
tabInitial = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]


#############################################################################################################
########################################### Ne pas modifier #################################################
#############################################################################################################

# Création du terrain
tabFinal = creationTerrain(tailleTerrain,tabInitial,variabilite)

# Création de l'image
image = constructionImage(tailleTerrain,tabFinal,hauteurMaximale)

# Affichage de l'image et du terrain 
affichageImageTerrain(tailleTerrain,tabFinal,hauteurMaximale,image)

# %% [markdown]
# 1/ En <u>testant diverses valeurs</u> et en <u>respectant son type</u> , <b>indiquer</b> le rôle de la variable `variabilite`.

# %% [markdown]
# 2/ <b>Proposer</b> une valeur à `variabilite` pour obtenir un terrain réaliste.
#
# ### <u>Appeler le professeur pour validation</u>

# %% [markdown]
# ## <u>Activité 4</u> : Le match : algorithme de Perlin vs algorithme diamant-carré
#
# On comparera ici la rapidité (temps mis pour exécuter l'algorithme) et l'optimisation (qui restera subjective).
#
# 1/ Le programme suivant mesure le temps mis par chaque algorithme pour exécuter la génération d'un terrain. <b>Compléter</b> le tableau suivant en modifiant la variable `tailleTerrain` si besoin et <b>conclure</b> sur l'algorithme le plus rapide.

# %% [markdown]
# <table border="1">
#   <tr>
#     <td>Taille du terrain</td>
#     <td>256</td>
#     <td>512</td>
#     <td>1024</td>
#   </tr>
#   <tr>
#     <td>Durée de l'algorithme de Perlin (en secondes au centième près) </td>
#     <td></td>
#     <td></td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Durée de l'algorithme diamant-carré (en secondes au centième près) </td>
#     <td></td>
#     <td></td>
#     <td></td>
#   <tr>
# </table>

# %%
with open('FonctionsAuxiliaires.py') as f : exec(f.read())


##########################################################################################################           
################################## Paramètres du terrain #################################################
##########################################################################################################

# Valeurs pour tailleTerrain : 256,512 ou 1024
tailleTerrain = 256



################################ A ne pas modifier (sauf question 3) !! ##################################
# Variable de l'algorithme de Perlin

hauteurMaximale = 100
nombreOctaves = 4
frequenceInitiale = 2
persistanceInitiale = 0.3
choixInterpolationCubique = True

###########################################################################################################
# Variable de l'agorithme diamant-carré

variabilite = 0.8


###########################################################################################################
########################### Ne pas changer la suite du programme ##########################################
###########################################################################################################

############################## Algorithme de Perlin ####################################################### 

# Initialisation des valeurs aléatoires de départ
tabInitial = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]



# Génération du calque définitif (valeurs finales des hauteurs du terrain)
st = time()
tabFinal = creationCalqueDefinitif(nombreOctaves,tailleTerrain,frequenceInitiale,tabInitial,
                            persistanceInitiale,choixInterpolationCubique)
print("La durée de la génération du terrain par l'algorithme de Perlin est de ",str(time()-st),"sec")

# Affichage de l'image et du terrain
# affichageTerrain(tailleTerrain,tabFinal,hauteurMaximale)   # A activer pour la question 3/

############################################################################################################


########################### Algorithme diamant-carré #######################################################

# Initialisation des valeurs aléatoires de départ
tailleTerrain += 1                            # Attention à la règle des 2^n + 1
tabInitial = [[randint(0,hauteurMaximale) for i in range(0,tailleTerrain)] for j in range(0,tailleTerrain)]


# Génération du calque définitif (valeurs finales des hauteurs du terrain)
st = time()
tabFinal = creationTerrain(tailleTerrain,tabInitial,variabilite)
print("La durée de la génération du terrain par l'algorithme diamant-carré est de ",str(time()-st),"sec")

# Affichage de l'image et du terrain
# affichageTerrain(tailleTerrain,tabFinal,hauteurMaximale)    # A activer pour la question 3/

#############################################################################################################

# %% [markdown]
# 2/ (**) <u><b>ENFIN DES MATHS</b></u> :) Quelle <i>semble</i> être la <b>complexité</b> de chacun de ces algorithmes (on s'aidera des données du tableau) ? <b>Justifier</b> la réponse.
#
# 3/ <b>Afficher</b> les terrains générés en <u>enlevant les hashtag</u> devant les fonctions `affichageTerrain` pour chaque algorithme dans le programme et l'exécuter (faire des tests, modifier des valeurs de variables si besoin). Quelle semble être l'algorithme rendant le terrain le plus réaliste ? <b>Justifier</b>.
#
# ### <u>Appeler le professeur pour validation</u>
